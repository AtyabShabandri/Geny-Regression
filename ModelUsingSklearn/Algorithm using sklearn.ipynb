# %% [markdown]
# # Algorithm using sklearn

# %%
#Importing packages
import pandas as pd
import numpy as np

# %%
#importing the dataset
df = pd.read_csv('data.csv')
df = df.drop(["id"],axis =1)
df
# Out:
#      bedrooms  floors  yr_built     price
# 0           3     1.0      1955  221900.0
# 1           3     2.0      1951  538000.0
# 2           2     1.0      1933  180000.0
# 3           4     1.0      1965  604000.0
# 4           3     1.0      1987  510000.0
# ..        ...     ...       ...       ...
# 395         2     1.0      1950  330000.0
# 396         5     1.0      1958  530000.0
# 397         4     1.0      1962  365000.0
# 398         3     1.5      1909  378750.0
# 399         4     1.5      1968  269900.0
#
# [400 rows x 4 columns]

# %%
X = df.iloc[:,:3]
y = df.price

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#linearRegression using sklearn
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#price predicted based on parents specifications
predictions = clf.predict(X_test)
clf.predict([[3,2,1982]])
# Out:
# array([530978.34453769])

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
reg = make_pipeline(StandardScaler(),SGDRegressor())
reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('sgdregressor', SGDRegressor())])

# %%
prediction = reg.predict(X_test)
reg.predict([[3, 2, 1983]])
# Out:
# array([528529.93716335])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Number of 1,2,3,4,5,6 bedrooms houses in the area
sns.countplot(x = 'bedrooms', data = df, palette='pastel')
plt.show()

# %%
# Price ranges in regards to number of bedrooms
sns.stripplot(x='bedrooms', y='price',data=df, palette='pastel')
plt.show()

# %%
# The price of houses in the area throughout the years
x = df.yr_built
y = df.price
sns.scatterplot(x, y, data=df, color = '#ef7b7d')
plt.show()
